# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch
import numpy as np
import pandas as pd
import os, getpass, sys
from huggingface_hub import notebook_login

# %%
os.environ["HUGGING_FACE_HUB_TOKEN"] = getpass.getpass("Token:")
assert os.environ["HUGGING_FACE_HUB_TOKEN"]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 os.environ["HUGGING_FACE_HUB_TOKEN"] = getpass.getpass("Token:")
# ----> 2 assert os.environ["HUGGING_FACE_HUB_TOKEN"]
#
# AssertionError:

# %%
notebook_login()

# %%
quantization_config = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_compute_dtype=torch.bfloat16)
nf4_config = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_quant_type="nf4")
double_quant_config = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_use_double_quant=True)

# %%
model_name = "Samuael/llama-2-7b-tebot-amharic"
# PATH = '/home/biniyam_ajaw/.cache/huggingface/hub/models--microsoft--phi-2'
model = AutoModelForCausalLM.from_pretrained(model_name, config=nf4_config)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 3
#       1 model_name = "Samuael/llama-2-7b-tebot-amharic"
#       2 # PATH = '/home/biniyam_ajaw/.cache/huggingface/hub/models--microsoft--phi-2'
# ----> 3 model = AutoModelForCausalLM.from_pretrained(model_name, config=nf4_config)
#
# File /opt/miniconda/envs/llm/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:566, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     564 elif type(config) in cls._model_mapping.keys():
#     565     model_class = _get_model_class(config, cls._model_mapping)
# --> 566     return model_class.from_pretrained(
#     567         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     568     )
#     569 raise ValueError(
# ...

# %%
last_layer_params = list(model.parameters())[-1]
num_params_last_layer = sum(p.numel() for p in last_layer_params)
print(f"Number of parameters in the last layer is {num_params_last_layer} ")
# Out:
# Number of parameters in the last layer is 51200
